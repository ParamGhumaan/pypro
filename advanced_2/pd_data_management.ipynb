# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df[ 'job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#              job_title_short  \
# 560156     Software Engineer
# 743795        Data Scientist
# 297255        Data Scientist
# 99399           Data Analyst
# 307448          Data Analyst
# 710738          Data Analyst
# 734652         Data Engineer
# 453386  Senior Data Engineer
# 4024          Data Scientist
# 340152        Data Scientist
#
#                                                 job_title  \
# 560156                                       Sr. Engineer
# 743795         Manager Data Science & Analytics - Flights
# 297255                                Lead Data Scientist
# 99399                                        Data Analyst
# 307448                                       Data Analyst
# 710738  Remote Work Opportunity in Oman | Data Collect...
# 734652                              Network Data Engineer
# 453386  Senior Cloud Data Engineer - TS/SCI with Polyg...
# 4024    Data Scientist (f/m/d) Natural Language Proces...
# 340152                                     Data Scientist
#
#                                job_location                  job_via  \
# 560156                             Malaysia       via BeBee Malaysia
# 743795               Amsterdam, Netherlands             via LinkedIn
# 297255           Mumbai, Maharashtra, India          via BeBee India
# 99399          Cabuyao, Laguna, Philippines      via Jobs - WhatJobs
# 307448                            Singapore      via BeBee Singapore
# 710738                             Anywhere  via LinkedIn سلطنة عمان
# 734652                          Orlando, FL                 via Dice
# 453386                          Hanover, MD       via Clearance Jobs
# 4024                       Barcelona, Spain               via Indeed
# 340152  Gôh-Djiboua District, Côte d'Ivoire              via Fidanto
#
#                job_schedule_type  job_work_from_home search_location  \
# 560156                 Full-time               False        Malaysia
# 743795                 Full-time               False     Netherlands
# 297255                 Full-time               False           India
# 99399                  Full-time               False     Philippines
# 307448                 Full-time               False       Singapore
# 710738                 Part-time                True            Oman
# 734652  Contractor and Temp work               False         Georgia
# 453386                 Full-time               False         Georgia
# 4024                   Full-time               False           Spain
# 340152                Contractor               False   Côte d'Ivoire
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 560156 2023-11-17 04:21:07                  False                 False
# 743795 2023-07-11 20:24:28                  False                 False
# 297255 2023-06-23 17:54:08                  False                 False
# 99399  2023-07-26 00:15:00                  False                 False
# 307448 2023-12-26 17:14:11                  False                 False
# 710738 2023-07-28 02:53:29                  False                 False
# 734652 2023-09-06 21:54:21                   True                 False
# 453386 2023-02-02 15:02:53                  False                  True
# 4024   2023-07-20 13:51:17                  False                 False
# 340152 2023-01-26 23:53:25                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 560156       Malaysia        None              NaN              NaN
# 743795    Netherlands        None              NaN              NaN
# 297255          India        None              NaN              NaN
# 99399     Philippines        None              NaN              NaN
# 307448      Singapore        None              NaN              NaN
# 710738           Oman        None              NaN              NaN
# 734652  United States        hour              NaN             55.0
# 453386  United States        None              NaN              NaN
# 4024            Spain        None              NaN              NaN
# 340152  Côte d'Ivoire        None              NaN              NaN
#
#                           company_name  \
# 560156  Jinko Solar Technology Sdn Bhd
# 743795                     Booking.com
# 297255                        Unilever
# 99399                           Henkel
# 307448       WECHAIN FINTECH PTE. LTD.
# 710738                           Appen
# 734652            K-Tek Resourcing LLC
# 453386                 Applied Insight
# 4024                    Siemens Energy
# 340152    CA GLOBAL AFRICA RECRUITMENT
#
#                                                job_skills  \
# 560156                                               None
# 743795    ['go', 'sql', 'python', 'r', 'hadoop', 'spark']
# 297255                         ['azure', 'hadoop', 'sap']
# 99399   ['python', 'sql', 'r', 'databricks', 'pyspark'...
# 307448                              ['python', 'tableau']
# 710738                                  ['go', 'windows']
# 734652                                               None
# 453386  ['sql', 'java', 'python', 'nosql', 'aws', 'azu...
# 4024                                      ['python', 'r']
# 340152                                               None
#
#                                           job_type_skills
# 560156                                               None
# 743795  {'libraries': ['hadoop', 'spark'], 'programmin...
# 297255  {'analyst_tools': ['sap'], 'cloud': ['azure'],...
# 99399   {'analyst_tools': ['power bi', 'excel'], 'clou...
# 307448  {'analyst_tools': ['tableau'], 'programming': ...
# 710738         {'os': ['windows'], 'programming': ['go']}
# 734652                                               None
# 453386  {'analyst_tools': ['excel'], 'async': ['jira']...
# 4024                     {'programming': ['python', 'r']}
# 340152                                               None

# %%
df_altered = df.copy()
